# %% [markdown]
# # Knut Edvard Kjersem – Data analyst
# ## SME in restaurant and hotel
# * Full name: Knut Edvard Kjersem
# * Birth date: 28-09-86
# * Post code-city: 6165 Sæbø
# * Address: Øyragata 32
# * Country: Norway
# * Phone: +4797134503
# * Email: knutekjersem@gmail.com
#
# I have had long career in the kitchen. The last ten years of which I worked at the highest level of luxury hotels and restaurant. Extensive experience as a leader, with tangible results of excellence and business. Stepping over to my orignal degree to workin in data analytics. Used to working with a wide range of cultures, languages and people

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Loading my subjects which my Bachelor degree is comprosing of
df = pd.DataFrame({"INF150":("Programming", "2006 Autumn","15"),
             "IDA115":("Networks and Server Management", "2007 Spring","15"),
             "IDA105":("Human-Computer Interaction", "2006 Autumn","15"),
             "INF151":("Programming Practice", "2007 Spring","15"),
             "IBE209":("User Support and Training", "2007 Autumn","7.5"),
             "INF160":("Advanced Programming", "2008 Spring","15"),
             "IBE380":("Robust and Secure Systems", "2008 Autumn","15"),
             "IDA215":("Router Administration and Network Design", "2008 Spring","7.5"),
             "LOG205":("e-Business", "2008 Spring","15"),
             "IBE313":("XML-technology", "2008 Autumn","7.5"),
             "IBE620":("Work Study", "2008 Autumn","15"),
             "IBE210":("Database Applications", "2008 Autumn","15"),
             "IBE610":("Bachelor Degree Thesis", "2009 Spring","15"),
             "INFO100":("Basic Course in Information Science", "2005 Autumn","10"),
             "SV100":("Social Science Perspectives", "2005 Autumn","10"),
             "EXPHIL-SVSEM":("Examen Philosophicum", "2005 Autumn","10")}
)

#transpose, to a new frame because the Rows needs to be the Columns and vise versa
transcript = df.T  

#Giving the column a names after transpose
transcript.rename(
    columns={0: "subject_code", 1: "subject_name", 2: "ECTS"},
    inplace=True,)

# %%
transcript
# Out:
#                                           subject_code subject_name ECTS
# INF150                                     Programming  2006 Autumn   15
# IDA115                  Networks and Server Management  2007 Spring   15
# IDA105                      Human-Computer Interaction  2006 Autumn   15
# INF151                            Programming Practice  2007 Spring   15
# IBE209                       User Support and Training  2007 Autumn  7.5
# INF160                            Advanced Programming  2008 Spring   15
# IBE380                       Robust and Secure Systems  2008 Autumn   15
# IDA215        Router Administration and Network Design  2008 Spring  7.5
# LOG205                                      e-Business  2008 Spring   15
# IBE313                                  XML-technology  2008 Autumn  7.5
# IBE620                                      Work Study  2008 Autumn   15
# IBE210                           Database Applications  2008 Autumn   15
# ...

# %%
fig, ax = plt.subplots()
explode = (0, 0.4, 0, 0.0, 0.1, 0, 0, 0.2, 0, 0,0, 0.1, 0, 0, 0,0)
ax.pie(df.iloc[2].values, labels=df.iloc[2].keys(), autopct='%1.1f%%', explode=explode, 
       radius=1, shadow=True)

ax.legend( (df.iloc[0].keys() +" " +df.iloc[0].values),
          title="Subject",
          loc="center left",
          bbox_to_anchor=(1.5, 0, 0.5, 1))


ax.set_title("My bachelors degree in computer science", loc = 'center')

## Summary of subjects in bachelors degree
# Out:
# Text(0.5, 1.0, 'My bachelors degree in computer science')

# %% [markdown]
# ## Visualiazed proficiency

# %%
rm = pd.DataFrame({"Keyskil":("Theory of data analytics",
                            "Programming with Databases",
                            "Mastering Basic R",
                            "Excel as anylytical tool",
                            "SQL in Data analytics",
                            "Python with pandas and numpy",
                            "Tableau for visualization"),
                    "Proffiecency Data Analyst":(1,5,7.5,7.5,8.5,9,8)})

rm = rm.sort_values(by=["Proffiecency Data Analyst"])

# %%
 
plt.plot(rm["Proffiecency Data Analyst"].values, rm["Keyskil"].values)
plt.xlabel("Value of skill")  
plt.title("Knut Edvard's proficiency as data analyst")  # add title
plt.show()

# %% [markdown]
# ## Programming proficiency
#
# ### C++
# Learned this OOP language to do to my bachelor thesis. A GUI for apache webserver made with the QT framework
# ### Java with Spring boot
# Learned java at school. But picked up spring boot to prepare for a job interview
# ### Javascript
# Started looking into this as foundation for learning react
# ### React
# I thought myself the absolute basics of this framework/language
# ### .Net
# Taught at school. Havent done anythin with it since then.
#
# ## Literal languages
# * Norwegian, mother tongue
# * English, working language since 2008
# * French, enough to survive in a french speaking kitchen
# * German, basic

# %% [markdown]
# ## Projects
# ### Fish export project
# Exploring and mapping out new markets for a fish exporting company
# All data cleaning and some viz done in R. Also one basic tableau viz
#
# https://github.com/knutekje/AFE-workbook
#
# ### Hotel chain project
# Done all in SQL to make a targeted marketing campaign for this hotel chain
#
# https://github.com/knutekje/Hotel_World
#
# ### Google course project :Tiktok
# Cleaning and inspecting data. All done in Python with pandas
#
# https://github.com/knutekje/python-google
